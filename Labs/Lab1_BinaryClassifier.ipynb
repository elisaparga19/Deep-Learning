# %% [markdown]
# # Binary classifier with a sigmoid neuron

# %% [markdown]
# Let's implement a simple sigmoid neuron to classify 2D points. First, we only need two libraries:

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# We will create two random distributions of points. One of the distribution is shifted, so there is a clear linear separation between both sets. We build a dataset with the points.

# %%
#Let's create a dataset of 2D points. The distribution is only shifted 3.5 units
X1 = np.random.randn(1000, 2)
X2 = np.random.randn(1000, 2) + 3.5

#The first 750 points of each distribution go in the training set
X_train = np.concatenate([X1[:750,:], X2[:750,:]], axis=0)

#The last 250 points of each distribution go in the test set
X_test = np.concatenate([X1[750:,:], X2[750:,:]], axis=0)

#We also create the labels
Y1 = np.zeros((1000, 1)) #The points in the first distribution have class 0
Y2 = np.ones((1000, 1)) # The points in the second distribution have class 1

#The first 750 labels of each distribution go in the training set
Y_train = np.concatenate([Y1[:750], Y2[:750]], axis=0)

#The last 250 labels of each distribution go in the test set
Y_test = np.concatenate([Y1[750:], Y2[750:]], axis=0)


#Plot the training set
plt.scatter(X_train[:750,0], X_train[:750,1], color='b')
plt.scatter(X_train[750:,0], X_train[750:,1], color='r')
plt.show()
# Out:
# (1500, 2)

# %% [markdown]
# We develop the neural network and the gradient descent algorithm for learning

# %%
#Definition of sigmoid function
def sigmoid(x):
    return 1/(1 + np.exp(-x))


#Let's implement the gradient descent algorithm

#Initialize random parameters
w1 = 2*np.random.rand(1) - 1
w2 = 2*np.random.rand(1) - 1
b = 2*np.random.rand(1) - 1

#Initialize hiper-parameters
learning_rate = 0.001
num_epochs = 100

#Log lists
log_train = []
log_test = []

#Iterate over the epochs
for i in range(num_epochs):
    cost = 0
    
    #Foe each epoch, iterate over the training samples
    for j in range(X_train.shape[0]):
        #Compute the linear function
        z = w1 * X_train[j,0] + w2 * X_train[j, 1] + b
        #Compute the activation function (sigmoid)
        y1 = sigmoid(z)
        
        #Compute error and cost for this sample
        error = y1 - Y_train[j]
        cost = cost + error**2
        
        #Compute the derivatives for each parameter        
        dw1 = error*y1*(1-y1)*X_train[j,0]
        dw2 = error*y1*(1-y1)*X_train[j,1]
        db = error*y1*(1-y1)
        
        #Perform the update rules        
        w1 = w1 - learning_rate*dw1
        w2 = w2 - learning_rate*dw2
        b = b - learning_rate*db
    
    #At the end of the epoch, we compute the total cost of the epoch
    cost = cost/(2*X_train.shape[0])
    log_train.append(cost)
    
    #We verify how good is the model so far, by computing the accuracy in the test set
    test_output = []
    cost = 0
    
    #Iterate over the test samples
    for j in range(X_test.shape[0]):
        #Compute the output of the neuron
        y1 = sigmoid(w1 * X_test[j,0] + w2 * X_test[j, 1] + b)
        cost = cost + (y1 - Y_test[j])**2
        test_output.append(y1)
    
    #Average the cost over the test set
    cost = cost / (2*X_test.shape[0])
    log_test.append(cost)
    
    test_output = np.asarray(test_output)
    test_output = (test_output >= 0.5)
    
    #Compare the output of the network with the correct labels
    correct = (test_output == Y_test).sum()
    
    print('Epoch {}/{}: loss = {}: Test accuracy={}'.format(i, num_epochs, cost, (100*correct)/test_output.shape[0]))
# Out:
# Epoch 0/100: loss = [0.10203795]: Test accuracy=66.2
# Epoch 1/100: loss = [0.09762764]: Test accuracy=68.0
# Epoch 2/100: loss = [0.09323335]: Test accuracy=69.6
# Epoch 3/100: loss = [0.08886269]: Test accuracy=70.6
# Epoch 4/100: loss = [0.08452483]: Test accuracy=71.6
# Epoch 5/100: loss = [0.08023063]: Test accuracy=72.8
# Epoch 6/100: loss = [0.0759929]: Test accuracy=73.4
# Epoch 7/100: loss = [0.0718264]: Test accuracy=74.4
# Epoch 8/100: loss = [0.06774792]: Test accuracy=76.2
# Epoch 9/100: loss = [0.06377624]: Test accuracy=78.4
# Epoch 10/100: loss = [0.05993193]: Test accuracy=80.2
# Epoch 11/100: loss = [0.0562371]: Test accuracy=81.6
# Epoch 12/100: loss = [0.05271477]: Test accuracy=83.2
# Epoch 13/100: loss = [0.04938809]: Test accuracy=84.2
# Epoch 14/100: loss = [0.04627904]: Test accuracy=86.0
# Epoch 15/100: loss = [0.04340672]: Test accuracy=87.0
# Epoch 16/100: loss = [0.04078527]: Test accuracy=88.6
# Epoch 17/100: loss = [0.03842171]: Test accuracy=90.0
# Epoch 18/100: loss = [0.03631422]: Test accuracy=91.8
# Epoch 19/100: loss = [0.03445163]: Test accuracy=92.8
# Epoch 20/100: loss = [0.03281435]: Test accuracy=93.6
# Epoch 21/100: loss = [0.03137688]: Test accuracy=94.8
# Epoch 22/100: loss = [0.03011103]: Test accuracy=96.0
# Epoch 23/100: loss = [0.02898903]: Test accuracy=96.2
# Epoch 24/100: loss = [0.02798583]: Test accuracy=96.8
# Epoch 25/100: loss = [0.02708026]: Test accuracy=97.0
# Epoch 26/100: loss = [0.02625524]: Test accuracy=97.0
# Epoch 27/100: loss = [0.02549739]: Test accuracy=97.4
# Epoch 28/100: loss = [0.02479636]: Test accuracy=97.4
# Epoch 29/100: loss = [0.02414415]: Test accuracy=97.6
# Epoch 30/100: loss = [0.02353455]: Test accuracy=97.6
# Epoch 31/100: loss = [0.0229626]: Test accuracy=97.6
# Epoch 32/100: loss = [0.02242433]: Test accuracy=97.6
# Epoch 33/100: loss = [0.02191644]: Test accuracy=98.0
# Epoch 34/100: loss = [0.02143615]: Test accuracy=98.0
# Epoch 35/100: loss = [0.0209811]: Test accuracy=98.0
# Epoch 36/100: loss = [0.02054924]: Test accuracy=98.2
# Epoch 37/100: loss = [0.02013875]: Test accuracy=98.4
# Epoch 38/100: loss = [0.01974802]: Test accuracy=98.4
# Epoch 39/100: loss = [0.01937564]: Test accuracy=98.4
# Epoch 40/100: loss = [0.0190203]: Test accuracy=98.4
# Epoch 41/100: loss = [0.01868086]: Test accuracy=98.4
# Epoch 42/100: loss = [0.01835624]: Test accuracy=98.4
# Epoch 43/100: loss = [0.01804548]: Test accuracy=98.6
# Epoch 44/100: loss = [0.01774772]: Test accuracy=98.6
# Epoch 45/100: loss = [0.01746214]: Test accuracy=98.6
# Epoch 46/100: loss = [0.017188]: Test accuracy=98.6
# Epoch 47/100: loss = [0.01692463]: Test accuracy=98.6
# Epoch 48/100: loss = [0.01667139]: Test accuracy=98.6
# Epoch 49/100: loss = [0.01642771]: Test accuracy=98.6
# Epoch 50/100: loss = [0.01619305]: Test accuracy=98.6
# Epoch 51/100: loss = [0.01596692]: Test accuracy=98.6
# Epoch 52/100: loss = [0.01574884]: Test accuracy=98.6
# Epoch 53/100: loss = [0.01553841]: Test accuracy=98.6
# Epoch 54/100: loss = [0.0153352]: Test accuracy=98.6
# Epoch 55/100: loss = [0.01513886]: Test accuracy=98.6
# Epoch 56/100: loss = [0.01494904]: Test accuracy=98.6
# Epoch 57/100: loss = [0.01476541]: Test accuracy=98.8
# Epoch 58/100: loss = [0.01458767]: Test accuracy=98.8
# Epoch 59/100: loss = [0.01441554]: Test accuracy=98.8
# Epoch 60/100: loss = [0.01424875]: Test accuracy=98.8
# Epoch 61/100: loss = [0.01408706]: Test accuracy=98.8
# Epoch 62/100: loss = [0.01393023]: Test accuracy=98.8
# Epoch 63/100: loss = [0.01377803]: Test accuracy=98.8
# Epoch 64/100: loss = [0.01363027]: Test accuracy=98.8
# Epoch 65/100: loss = [0.01348675]: Test accuracy=98.8
# Epoch 66/100: loss = [0.01334728]: Test accuracy=98.8
# Epoch 67/100: loss = [0.01321169]: Test accuracy=98.8
# Epoch 68/100: loss = [0.01307983]: Test accuracy=98.8
# Epoch 69/100: loss = [0.01295152]: Test accuracy=98.8
# Epoch 70/100: loss = [0.01282664]: Test accuracy=98.8
# Epoch 71/100: loss = [0.01270504]: Test accuracy=98.8
# Epoch 72/100: loss = [0.01258659]: Test accuracy=98.8
# Epoch 73/100: loss = [0.01247117]: Test accuracy=98.8
# Epoch 74/100: loss = [0.01235865]: Test accuracy=98.8
# Epoch 75/100: loss = [0.01224894]: Test accuracy=98.8
# Epoch 76/100: loss = [0.01214191]: Test accuracy=98.8
# Epoch 77/100: loss = [0.01203748]: Test accuracy=98.8
# Epoch 78/100: loss = [0.01193555]: Test accuracy=98.8
# Epoch 79/100: loss = [0.01183602]: Test accuracy=98.8
# Epoch 80/100: loss = [0.01173881]: Test accuracy=98.8
# Epoch 81/100: loss = [0.01164384]: Test accuracy=98.8
# Epoch 82/100: loss = [0.01155102]: Test accuracy=98.8
# Epoch 83/100: loss = [0.01146029]: Test accuracy=98.8
# Epoch 84/100: loss = [0.01137158]: Test accuracy=98.8
# Epoch 85/100: loss = [0.0112848]: Test accuracy=98.8
# Epoch 86/100: loss = [0.01119991]: Test accuracy=98.8
# Epoch 87/100: loss = [0.01111683]: Test accuracy=98.8
# Epoch 88/100: loss = [0.01103552]: Test accuracy=98.8
# Epoch 89/100: loss = [0.0109559]: Test accuracy=98.8
# Epoch 90/100: loss = [0.01087793]: Test accuracy=98.8
# Epoch 91/100: loss = [0.01080155]: Test accuracy=98.8
# Epoch 92/100: loss = [0.01072672]: Test accuracy=98.8
# Epoch 93/100: loss = [0.01065338]: Test accuracy=98.8
# Epoch 94/100: loss = [0.0105815]: Test accuracy=98.8
# Epoch 95/100: loss = [0.01051102]: Test accuracy=98.8
# Epoch 96/100: loss = [0.01044191]: Test accuracy=98.8
# Epoch 97/100: loss = [0.01037412]: Test accuracy=98.8
# Epoch 98/100: loss = [0.01030761]: Test accuracy=98.8
# Epoch 99/100: loss = [0.01024236]: Test accuracy=98.8

# %%
#Plot of historic logs
plt.plot(log_train, color='b')
plt.plot(log_test, color='r')

plt.show()

# %%
#Plot the boundary decision

x1_val = np.linspace(X_train[:,0].min(), X_train[:,0].max(), 100)
x2_val = (-b - (w1 * x1_val))/w2


plt.scatter(X_train[:750, 0], X_train[:750, 1], color='b')
plt.scatter(X_train[750:, 0], X_train[750:, 1], color='r')
plt.plot(x1_val, x2_val, 'g')
